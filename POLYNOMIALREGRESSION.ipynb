# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyansh-114/MACHINE_LEARNING_MODELS/blob/main/POLYNOMIALREGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X =6*np.random.rand(100,1)-3
Y= 0.5*X**2 + 1.5*X +2 + np.random.randn(100,1)
##  quadratic eqn = 0.5*x^2 + 1.5*x + 2 +outliers

# %%
## now plot the curve
plt.scatter(X,Y,color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
## Lets implement Simple Linear Regression
from sklearn.linear_model import LinearRegression
regression_1=LinearRegression()

# %%
# this is bascially the models

regression_1.fit(X_train,Y_train)
y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
score=r2_score(Y_test,y_pred)
print(score)
# Out:
# 0.653338430648706

# %%
## now we print the rmse and rae score
mse=mean_squared_error(Y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(Y_test,y_pred)

# %%
print(mse)
print(mae)
print(rmse)
# Out:
# 4.979415549618302
# 1.83944849586226
# 2.2314604073606823

# %%
## now print the residuals
residuals = Y_test - y_pred

# %%
print(residuals)
# Out:
# [[-1.015898  ]
#  [ 2.67100907]
#  [ 4.590835  ]
#  [ 1.11025025]
#  [-0.56417432]
#  [-2.22152521]
#  [ 0.38256221]
#  [-2.74334939]
#  [ 0.62375863]
#  [ 2.9456756 ]
#  [ 3.90912716]
#  [ 1.84287535]
#  [ 0.1466618 ]
#  [-0.71728945]
#  [-2.85334116]
#  [-0.79340822]
#  [-2.99049466]
#  [ 1.10777886]
#  [ 0.63190659]
#  [ 2.927049  ]]

# %%
## here we have a distribution of the residuals
import matplotlib.pyplot as plt

import seaborn as sns

sns.histplot(residuals, kde=True)
plt.title("Residual Distribution with KDE")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(residuals, label="Residual Distribution")

# vertical line at 0
plt.axvline(x=0, color='red', linestyle='--', label='Zero')

plt.title("Residual Distribution Curve")
plt.xlabel("Residuals")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# reshape X
X_plot = np.array(X).reshape(-1, 1)
Y_plot = np.array(Y)

# predictions
Y_pred = regression.predict(X_plot)

# sort for clean line
sorted_idx = np.argsort(X_plot.flatten())

# scatter plot (data points)
plt.scatter(X_plot, Y_plot, label="Data Points")

# regression line
plt.plot(X_plot[sorted_idx], Y_pred[sorted_idx], label="Best Fit Line")

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression Line with Data Points")
plt.legend()

plt.show()

# %%
## now we apply the polynomial transfromation
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2,include_bias=True)
X_train_poly=poly.fit_transform(X_train)
#We don’t fit on test data because it should remain unseen; otherwise, the model cheats.”
X_test_poly=poly.transform(X_test)

# %%
X_train_poly
# Out:
# array([[ 1.00000000e+00,  4.55801921e-01,  2.07755392e-01],
#        [ 1.00000000e+00,  2.50890797e+00,  6.29461920e+00],
#        [ 1.00000000e+00,  1.20714734e+00,  1.45720471e+00],
#        [ 1.00000000e+00,  1.72327448e-01,  2.96967494e-02],
#        [ 1.00000000e+00, -1.62668181e+00,  2.64609372e+00],
#        [ 1.00000000e+00, -1.83687656e+00,  3.37411549e+00],
#        [ 1.00000000e+00, -1.67408682e+00,  2.80256668e+00],
#        [ 1.00000000e+00, -1.22760677e+00,  1.50701839e+00],
#        [ 1.00000000e+00,  1.53537849e+00,  2.35738712e+00],
#        [ 1.00000000e+00, -2.20926404e+00,  4.88084758e+00],
#        [ 1.00000000e+00, -2.66053011e+00,  7.07842046e+00],
#        [ 1.00000000e+00,  2.98543778e-01,  8.91283876e-02],
#        [ 1.00000000e+00,  2.04739684e+00,  4.19183382e+00],
#        [ 1.00000000e+00, -3.13946951e-01,  9.85626883e-02],
#        [ 1.00000000e+00, -2.32969403e+00,  5.42747426e+00],
#        [ 1.00000000e+00,  5.75982105e-01,  3.31755385e-01],
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
## this is basically our Model
regression=LinearRegression()
regression.fit(X_train_poly,Y_train)
y_pred=regression.predict(X_test_poly)

# %%
## now we are calcualting the score matrices
score=r2_score(Y_test,y_pred)
print(score)
# Out:
# 0.9069309132028418

# %%
## now place all the other score metrices
mse=mean_squared_error(Y_test,y_pred)
rmse=np.sqrt(mse)
rae=mean_absolute_error(Y_test,y_pred)

# %%
print(mse)
print(rmse)
print(rae)
# Out:
# 1.3368359776763215
# 1.1562162330966996
# 1.0116507248320117

# %%
residuals=Y_test-y_pred

# %%
sns.kdeplot(residuals, label="Residual Distribution")

# vertical line at 0
plt.axvline(x=0, color='red', linestyle='--', label='Zero')

plt.title("Residual Distribution Curve")
plt.xlabel("Residuals")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Scatter plot (original data)
plt.scatter(X, Y, color='blue', label='Data Points')

# Step 2: Create smooth X values for curve
X_new = np.linspace(X.min(), X.max(), 100).reshape(100,1)

# Step 3: Transform using polynomial features
X_new_poly = poly.transform(X_new)

# Step 4: Predict using model
Y_new = regression.predict(X_new_poly)

# Step 5: Plot curve
plt.plot(X_new, Y_new, color='red', linewidth=2, label='Polynomial Curve')

# Labels
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Polynomial Regression Fit")

plt.legend()
plt.show()

# %%
sns.histplot(residuals, kde=True)
plt.show()

# %%
plt.scatter(X_train,regression.predict(X_train_poly),color='red')

# %%
## now predection for the new data
x_new=np.linspace(-3,3,200).reshape(200,1)
x_new_poly=poly.transform(x_new)
y_new_poly=regression.predict(x_new_poly)

# %%
## now plot the curve of the new points
plt.plot(x_new,y_new_poly,color='red')
plt.scatter(X,Y )

# %%
import numpy as np

# New input
X_new = np.array([[2]])

# Transform
X_new_poly = poly.transform(X_new)

# Predict
y_pred = regression.predict(X_new_poly)

print("Prediction:", y_pred)
# Out:
# Prediction: [[6.84530388]]
